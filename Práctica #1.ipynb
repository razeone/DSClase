# %%
a = 1

# %%
print(a)
# Out:
# 1

# %%
a = 'Hola Mundo'
print(a)
# Out:
# Hola Mundo

# %%
nombre = 'Jorge'
print(nombre)
# Out:
# Jorge

# %%
lista = [1,2,3,4,5]

# %%
print(lista[0])
# Out:
# 1

# %%
univ = 'Universidad Panaméricana'

# %%
univ[:-1]
# Out:
# 'Universidad Panamérican'

# %%
univ[::-1]
# Out:
# 'anacirémanaP dadisrevinU'

# %%
lista_nombres = ['Juan', 'Pedro', 'María', 'Daniel']

# %%
for i in lista_nombres:
    print('Hola {}'.format(i))
# Out:
# Hola Juan
# Hola Pedro
# Hola María
# Hola Daniel

# %%
a = 15
if a > 10:
    print('Success')
else:
    print('Error')
# Out:
# Success

# %%
import pylab

# %%
equis = range(10)
y = [x*x*x for x in equis]
pylab.plot(equis,y, 'o')
pylab.plot?

# %%
y = [22,22,22,23,22,22,23,22,27,29,29,31,41,37]
pylab.hist(y, bins = 10)
# Out:
# (array([8., 0., 1., 2., 1., 0., 0., 1., 0., 1.]),
#  array([22. , 23.9, 25.8, 27.7, 29.6, 31.5, 33.4, 35.3, 37.2, 39.1, 41. ]),
#  <a list of 10 Patch objects>)

# %%
import pylab as plt

# %%
import numpy as np

# %%
x = [0,0.3,0.6,0.9,1.2,1.5,1.8,2.1,2.4]
y = np.sin(x)
y2 = np.cos(x)
plt.plot(x,y, '--')
plt.plot(x,y2, 'r')

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/median_price.csv')

# %%
df.head(2)
# Out:
#         RegionName       City State      Metro CountyName  SizeRank  \
# 0  Upper East Side   New York    NY   New York   New York         1
# 1    Spring Valley  Las Vegas    NV  Las Vegas      Clark         2
#
#       2010-01  2010-02     2010-03     2010-04     ...           2015-12  \
# 0  819.487179   781.25  784.985549  798.857143     ...       1192.959583
# 1         NaN      NaN         NaN         NaN     ...        104.097961
#
#        2016-01      2016-02      2016-03      2016-04      2016-05  \
# 0  1250.000000  1276.059647  1264.240506  1284.686536  1170.898029
# 1   106.642942   107.350858   107.530283   109.857143   112.582369
#
#        2016-06      2016-07      2016-08      2016-09
# 0  1352.753392  1367.004092  1396.504828  1366.943942
# 1   106.944444   106.944444   106.597222   109.203297
#
# [2 rows x 87 columns]

# %%
df.iloc[0:3]
# Out:
#         RegionName         City State                           Metro  \
# 0  Upper East Side     New York    NY                        New York
# 1    Spring Valley    Las Vegas    NV                       Las Vegas
# 2        Hollywood  Los Angeles    CA  Los Angeles-Long Beach-Anaheim
#
#     CountyName  SizeRank     2010-01  2010-02     2010-03     2010-04  \
# 0     New York         1  819.487179   781.25  784.985549  798.857143
# 1        Clark         2         NaN      NaN         NaN         NaN
# 2  Los Angeles         3         NaN      NaN         NaN         NaN
#
#       ...           2015-12      2016-01      2016-02      2016-03  \
# 0     ...       1192.959583  1250.000000  1276.059647  1264.240506
# 1     ...        104.097961   106.642942   107.350858   107.530283
# 2     ...        688.976378   663.563830   654.767041   567.960963
#
#        2016-04      2016-05      2016-06      2016-07      2016-08  \
# ...

# %%
df['State']
# Out:
# 0     NY
# 1     NV
# 2     CA
# 3     NY
# 4     NY
# 5     NV
# 6     CA
# 7     NY
# 8     NY
# 9     NY
# 10    NY
# 11    FL
# 12    TN
# 13    NY
# 14    TX
# 15    TX
# 16    IL
# 17    HI
# 18    CA
# 19    WA
# 20    NY
# 21    VA
# 22    NY
# 23    NY
# 24    VA
# 25    FL
# 26    NV
# 27    FL
# 28    HI
# 29    MA
#       ..
# 37    FL
# 38    NY
# 39    GA
# 40    NY
# 41    FL
# 42    VA
# 43    CA
# 44    NY
# 45    FL
# 46    NY
# 47    FL
# 48    GA
# 49    FL
# 50    FL
# 51    NY
# 52    WA
# 53    KY
# 54    MN
# 55    GA
# 56    FL
# 57    FL
# 58    FL
# 59    FL
# 60    FL
# 61    FL
# 62    FL
# 63    FL
# 64    NV
# 65    FL
# 66    PA
# Name: State, Length: 67, dtype: object

# %%
df['State'].unique()
# Out:
# array(['NY', 'NV', 'CA', 'FL', 'TN', 'TX', 'IL', 'HI', 'WA', 'VA', 'MA',
#        'GA', 'DC', 'KY', 'MN', 'PA'], dtype=object)

# %%
df['City'].unique()
# Out:
# array(['New York', 'Las Vegas', 'Los Angeles', 'San Jose', 'Miami',
#        'Memphis', 'Dallas', 'Houston', 'Chicago', 'Honolulu', 'Seattle',
#        'Alexandria', 'Miami Beach', 'Boston', 'Orlando', 'Atlanta',
#        'Washington', 'Arlington', 'Long Beach', 'Delray Beach',
#        'Pompano Beach', 'Louisville', 'Saint Paul', 'Hollywood',
#        'Panama City', 'Fort Lauderdale', 'Philadelphia'], dtype=object)

# %%
df[df['City']=='New York']
# Out:
#             RegionName      City State     Metro CountyName  SizeRank  \
# 0      Upper East Side  New York    NY  New York   New York         1
# 3         Williamsburg  New York    NY  New York      Kings         4
# 4               Harlem  New York    NY  New York   New York         5
# 7       Sheepshead Bay  New York    NY  New York      Kings         8
# 8         Forest Hills  New York    NY  New York     Queens         9
# 9      Jackson Heights  New York    NY  New York     Queens        10
# 10            Gramercy  New York    NY  New York   New York        11
# 13             Chelsea  New York    NY  New York   New York        14
# 20             Clinton  New York    NY  New York   New York        21
# 22  Financial District  New York    NY  New York   New York        23
# 23   Flatiron District  New York    NY  New York   New York        24
# 30        Sutton Place  New York    NY  New York   New York        31
# ...

# %%
df.groupby('City').mean()
# Out:
#                   SizeRank     2010-01     2010-02     2010-03     2010-04  \
# City
# Alexandria       23.500000         NaN         NaN         NaN         NaN
# Arlington        43.000000         NaN         NaN         NaN         NaN
# Atlanta          44.750000  194.263702  196.319964  197.946962  202.405063
# Boston           30.000000         NaN         NaN         NaN         NaN
# Chicago          24.500000  351.113990  358.250000  359.270833  359.270833
# Dallas           15.000000         NaN         NaN         NaN         NaN
# Delray Beach     48.000000   34.366391   34.297521   33.746556   32.920110
# Fort Lauderdale  66.000000  212.825279  212.473245  222.352941  227.016023
# Hollywood        61.000000  185.183333  181.091052  183.908046  183.908046
# Honolulu         23.500000  552.599784  574.358974  572.556846  544.984104
# Houston          16.000000         NaN         NaN         NaN         NaN
# ...

# %%
df.groupby('City').sum()
# Out:
#                  SizeRank      2010-01      2010-02      2010-03      2010-04  \
# City
# Alexandria             47     0.000000     0.000000     0.000000     0.000000
# Arlington              43     0.000000     0.000000     0.000000     0.000000
# Atlanta               179   194.263702   196.319964   197.946962   202.405063
# Boston                 30     0.000000     0.000000     0.000000     0.000000
# Chicago                49   351.113990   358.250000   359.270833   359.270833
# Dallas                 15     0.000000     0.000000     0.000000     0.000000
# Delray Beach           48    34.366391    34.297521    33.746556    32.920110
# Fort Lauderdale        66   212.825279   212.473245   222.352941   227.016023
# Hollywood             122   185.183333   181.091052   183.908046   183.908046
# Honolulu               47   552.599784   574.358974   572.556846   544.984104
# Houston                16     0.000000     0.000000     0.000000     0.000000
# ...
